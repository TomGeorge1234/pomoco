# %%
# %load_ext autoreload
# %autoreload 2

import sys
import os
sys.path.append(os.path.abspath('..'))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import numpy as np 
import torch
import torch.nn as nn
from uuid import uuid4
import matplotlib.pyplot as plt
plt.style.use('../plotting/style_sheet.mplstyle')
from toy_rnn.dataset import Dataset
from plotting import plotting_utils
import sklearn
from toy_rnn.dataset import Dataset
from toy_rnn.rnn import MultiSetRNN
from synthetic_data.gaussian_process import GPSpikeGenerator

# %%
# Configuration
LATENT_DIM = 5
LATENT_TIMESCALE = 2.0
DT = 0.05
MEDIAN_FIRING_RATE = 40.0
NUM_NEURONS = 100

# %%
# Dataset, responsible for generating "synthetic" data 
data_generator = GPSpikeGenerator(
    latent_dim=LATENT_DIM,
    kernel_type="rbf",
    kernel_params={'tau' : LATENT_TIMESCALE},
    dt=DT,
    median_firing_rate=MEDIAN_FIRING_RATE,
    num_neurons=NUM_NEURONS,
)

# %%
trial = data_generator.sample(total_time=100.0)

time, latents, firing_rates, spike_counts, spike_times, spike_unit_ids = trial['time'], trial['latents'], trial['firing_rates'], trial['spike_counts'], trial['spike_times'], trial['spike_unit_ids']

# %%
from matplotlib.gridspec import GridSpec

data_fig = plt.figure(figsize=(5, 4)) # Increased figure width for histograms
gs = GridSpec(
    nrows=2, 
    ncols=1,
    figure=data_fig,
    height_ratios=[1, 1],

)

ax_latents = data_fig.add_subplot(gs[0, 0])
ax_spikes = data_fig.add_subplot(gs[1, 0], sharex=ax_latents)

def plot_latents(ax, time, latents):
    # Plot latents
    for l in range(latents.shape[1]):
        line = ax.plot(time, 3*l + latents[:, l])
        ax.fill_between(time, 3*l + latents[:, l], 3*l, alpha=0.3, color=line[0].get_color())
    ax.text(0.02, 0.9, "Latents", transform=ax.transAxes)
    ax.set_prop_cycle(None)  # reset color cycle
    ax.tick_params(axis='x', labelbottom=False) # Remove X labels from top plot
    ax.yaxis.set_visible(False) # Remove Y axis from latent plot
    ax.spines['left'].set_visible(False)

plot_latents(ax_latents, time, latents)

def plot_spikes(ax, time, spike_counts, firing_rates):
    # Plot spikes as an image
    im = ax.imshow((spike_counts/DT).T, aspect='auto', cmap='Greys', origin='lower', extent=[time[0], time[-1], 0, spike_counts.shape[1]])
    ax.text(0.02, 0.9, "Spikes", transform=ax.transAxes)
    ax.set_xlabel("Time (s)")

    # Plot spike count histogram
    ax_hist = ax.inset_axes([0.7, 0.8, 0.28, 0.18])
    ax_hist.hist(firing_rates.flatten(), bins=200, color='gray')
    ax_hist.tick_params(axis='y', labelleft=False) # Remove Y labels
    ax_hist.spines['left'].set_visible(False)
    ax_hist.yaxis.set_visible(False)
    ax_hist.set_xlabel("Firing rate (Hz)", fontdict={'size': 8})

plot_spikes(ax_spikes, time, spike_counts, firing_rates)

# Apply the utility function
plotting_utils.outset_axes(ax_latents)
plotting_utils.outset_axes(ax_spikes)

# %%
def fit_pcs(data, n_pcs=None, ground_truth=None,):
    from sklearn.decomposition import PCA
    pca = PCA(n_components=n_pcs)
    data_centered = data - np.mean(data, axis=0, keepdims=True)
    pcs = pca.fit_transform(data_centered)
    if ground_truth is not None:
        from sklearn.linear_model import LinearRegression
        assert pcs.shape == ground_truth.shape, "PCS and ground truth must have the same shape for alignment."
        reg = LinearRegression(fit_intercept=False).fit(pcs, ground_truth)
        pcs_aligned = reg.predict(pcs)
        return pcs_aligned
    return pcs

# %%
N_PCS = LATENT_DIM

pcs = fit_pcs(spike_counts, n_pcs=N_PCS, ground_truth=latents[:, :N_PCS])
r_sq = sklearn.metrics.r2_score(latents[:, :N_PCS], pcs)
print(f'Variance explained by first {N_PCS} PCs: {r_sq:.3f}')

#deepcopy the figure from before
from copy import deepcopy
data_fig_pcs = deepcopy(data_fig)
ax_latents = data_fig_pcs.axes[0]
ax_latents.set_prop_cycle(None)
for l in range(N_PCS):
    line = ax_latents.plot(time, 3*l + pcs[:, l], linestyle='--', alpha=0.7)

data_fig_pcs
# Out:
# Variance explained by first 5 PCs: 0.739

# %%
from toy_rnn import dataset


N_SETS = 10
BATCH_SIZE = 32

data_generators = [
    GPSpikeGenerator(
        latent_dim=np.random.randint(1, 10),
        kernel_type="rbf",
        kernel_params={'tau' : np.random.uniform(0.5, 5.0)},
        dt=DT,
        median_firing_rate=MEDIAN_FIRING_RATE,
        num_neurons=np.random.randint(50, 150),
    )
    for _ in range(N_SETS)
]

datasets = {
    str(uuid4())[:8] : Dataset(
        data_generator=gen,
        trial_length=10.0, 
    )
    for gen in data_generators
}

data_loaders = {
    ds_id: torch.utils.data.DataLoader(dataset,batch_size=BATCH_SIZE) for ds_id, dataset in datasets.items()
}

# %%
HIDDEN_SIZE = 64

# If cuda or mac GPU available, use that, else CPU
if torch.backends.mps.is_available():
    device = torch.device("mps")
elif torch.cuda.is_available():
    device = torch.device("cuda")
else:
    device = torch.device("cpu")
device = torch.device("cpu")
print(f"Using device: {device}")


# Init Model
model = MultiSetRNN(
    hidden_size=HIDDEN_SIZE,   # Size of LSTM hidden state
)

# Add the datasets to the model 
for ds_id, dataset in datasets.items():
    model.add_dataset(
        dataset_id=ds_id,
        input_size=dataset.data_generator.num_neurons,  # Input dimension (number of neurons)
        output_size=dataset.data_generator.latent_dim,  # Output dimension (latent dim)
    )

model.to(device)
# Out:
# Using device: cpu
# MultiSetRNN(
#   (input_heads): ModuleDict(
#     (cedbc95b): Linear(in_features=93, out_features=64, bias=True)
#     (30ddf7ba): Linear(in_features=59, out_features=64, bias=True)
#     (edd52f95): Linear(in_features=86, out_features=64, bias=True)
#     (1f61de3b): Linear(in_features=118, out_features=64, bias=True)
#     (362c8ae3): Linear(in_features=58, out_features=64, bias=True)
#     (7b688099): Linear(in_features=144, out_features=64, bias=True)
#     (48f8d2fb): Linear(in_features=52, out_features=64, bias=True)
#     (fa4d00c1): Linear(in_features=115, out_features=64, bias=True)
#     (ee828ecc): Linear(in_features=108, out_features=64, bias=True)
#     (4b3e8590): Linear(in_features=59, out_features=64, bias=True)
#   )
#   (output_heads): ModuleDict(
#     (cedbc95b): Linear(in_features=64, out_features=5, bias=True)
#     (30ddf7ba): Linear(in_features=64, out_features=3, bias=True)
#     (edd52f95): Linear(in_features=64, out_features=4, bias=True)
#     (1f61de3b): Linear(in_features=64, out_features=1, bias=True)
#     (362c8ae3): Linear(in_features=64, out_features=1, bias=True)
#     (7b688099): Linear(in_features=64, out_features=9, bias=True)
#     (48f8d2fb): Linear(in_features=64, out_features=9, bias=True)
#     (fa4d00c1): Linear(in_features=64, out_features=1, bias=True)
#     (ee828ecc): Linear(in_features=64, out_features=6, bias=True)
#     (4b3e8590): Linear(in_features=64, out_features=9, bias=True)
#   )
#   (lstm_backbone): LSTM(64, 64, batch_first=True, bidirectional=True)
#   (shared_proj): Linear(in_features=128, out_features=64, bias=True)
# )

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
criterion = nn.MSELoss()

max_steps = 1000

for step in range(max_steps):
    # Sample a random dataset
    ds_id = np.random.choice(list(data_loaders.keys()))
    dataloader = data_loaders[ds_id]
    batch = next(iter(dataloader))
    batch = {k: v.to(device,dtype=torch.float32) for k, v in batch.items()}    
    x = batch["spike_counts"]  # (Batch, Time, Neurons)
    y = batch["latents"]       # (Batch, Time, Latents)

    # Forward pass
    predictions = model(x, dataset_id=ds_id)  # (Batch, Time, Latents)
    
    # Loss calculation
    loss = criterion(predictions, y)
    
    # Backprop
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
    if step % 10 == 0:
        print(f"Step {step}, Loss: {loss.item():.4f}")
# Out:
# Step 0, Loss: 1.0060
# Step 10, Loss: 0.8897
# Step 20, Loss: 0.8142
# Step 30, Loss: 1.0796
# Step 40, Loss: 0.2428
# Step 50, Loss: 0.8151
# Step 60, Loss: 0.3774
# Step 70, Loss: 0.7595
# Step 80, Loss: 0.5381
# Step 90, Loss: 0.7325
# Step 100, Loss: 0.3424
# Step 110, Loss: 0.0965
# Step 120, Loss: 0.9108
# Step 130, Loss: 0.0569
# Step 140, Loss: 0.5223
# Step 150, Loss: 0.3566
# Step 160, Loss: 0.8055
# Step 170, Loss: 0.8051
# Step 180, Loss: 0.1719
# Step 190, Loss: 0.7924
# Step 200, Loss: 0.0263
# Step 210, Loss: 0.0836
# Step 220, Loss: 0.1107
# Step 230, Loss: 0.1849
# Step 240, Loss: 0.3191
# Step 250, Loss: 0.4228
# Step 260, Loss: 0.1911
# Step 270, Loss: 0.4868
# Step 280, Loss: 0.4009
# Step 290, Loss: 0.4722
# Step 300, Loss: 0.1459
# Step 310, Loss: 0.0253
# Step 320, Loss: 0.3838
# Step 330, Loss: 0.1668
# Step 340, Loss: 0.0974
# Step 350, Loss: 0.4328
# Step 360, Loss: 0.1018
# Step 370, Loss: 0.4856
# Step 380, Loss: 0.0856
# Step 390, Loss: 0.0218
# Step 400, Loss: 0.1049
# Step 410, Loss: 0.0205
# Step 420, Loss: 0.0739
# Step 430, Loss: 0.0207
# Step 440, Loss: 0.2699
# Step 450, Loss: 0.0919
# Step 460, Loss: 0.0153
# Step 470, Loss: 0.0725
# Step 480, Loss: 0.2990
# Step 490, Loss: 0.1789
# Step 500, Loss: 0.3207
# Step 510, Loss: 0.1642
# Step 520, Loss: 0.3046
# Step 530, Loss: 0.2905
# Step 540, Loss: 0.2568
# Step 550, Loss: 0.2369
# Step 560, Loss: 0.0842
# Step 570, Loss: 0.2407
# Step 580, Loss: 0.1121
# Step 590, Loss: 0.2608
# Step 600, Loss: 0.2152
# Step 610, Loss: 0.0387
# Step 620, Loss: 0.0802
# Step 630, Loss: 0.0328
# Step 640, Loss: 0.0658
# Step 650, Loss: 0.1328
# Step 660, Loss: 0.1832
# Step 670, Loss: 0.0971
# Step 680, Loss: 0.1587
# Step 690, Loss: 0.0596
# Step 700, Loss: 0.0610
# Step 710, Loss: 0.1598
# Step 720, Loss: 0.0233
# Step 730, Loss: 0.1619
# Step 740, Loss: 0.0148
# Step 750, Loss: 0.0188
# Step 760, Loss: 0.2468
# Step 770, Loss: 0.2316
# Step 780, Loss: 0.0664
# Step 790, Loss: 0.0215
# Step 800, Loss: 0.1809
# Step 810, Loss: 0.1530
# Step 820, Loss: 0.0861
# Step 830, Loss: 0.0237
# Step 840, Loss: 0.1541
# Step 850, Loss: 0.0177
# Step 860, Loss: 0.1237
# Step 870, Loss: 0.0274
# Step 880, Loss: 0.0200
# Step 890, Loss: 0.0170
# Step 900, Loss: 0.0561
# Step 910, Loss: 0.1487
# Step 920, Loss: 0.1208
# Step 930, Loss: 0.1357
# Step 940, Loss: 0.1386
# Step 950, Loss: 0.1341
# Step 960, Loss: 0.0160
# Step 970, Loss: 0.0985
# Step 980, Loss: 0.1192
# Step 990, Loss: 0.0127

# %%
# Evaluate and plot 
model.eval()
with torch.no_grad():
    # Get a batch of data
    batch = next(iter(dataloader))
    batch = {k: v.to(device).float() for k, v in batch.items()}
    x = batch["spike_counts"]
    y = batch["latents"]
    indices = batch["dataset_idx"].long()

    # Get model predictions
    predictions = model(x, indices)

# Convert to numpy for plotting
x_np = x.cpu().numpy()
y_np = y.cpu().numpy()
predictions_np = predictions.cpu().numpy()

# Plot true vs predicted latents for the first trial in the batch
trial_idx = 0
time = np.arange(y_np.shape[1]) * DT
fig, ax = plt.subplots(1,1, figsize=(5,2))

plot_latents(ax, time, y_np[trial_idx, :,])
for l in range(N_PCS):
    line = ax.plot(time, 3*l + predictions_np[trial_idx,:, l], linestyle='--', alpha=0.7)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 9
#       7 x = batch["spike_counts"]
#       8 y = batch["latents"]
# ----> 9 indices = batch["dataset_idx"].long()
#      11 # Get model predictions
#      12 predictions = model(x, indices)
#
# KeyError: 'dataset_idx'
